# %% [markdown]
# #  Data Consolidation and Cleaning

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Uploading the datasets

# %%
df1 = pd.read_csv('/content/events.csv')
df1.head(10)
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN
# 5  1433224086234     972639  view   22556            NaN
# 6  1433221923240     810725  view  443030            NaN
# 7  1433223291897     794181  view  439202            NaN
# 8  1433220899221     824915  view  428805            NaN
# 9  1433221204592     339335  view   82389            NaN

# %%
df2 = pd.read_csv('/content/item_properties_part1.1.csv')
df2.head(10)
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513
# 5  1436065200000  285026   available                                0
# 6  1434250800000   89534         213                          1121373
# 7  1431831600000  264312           6                           319724
# 8  1433646000000  229370         202                          1330310
# 9  1434250800000   98113         451                  1141052 n48.000

# %%
df3 = pd.read_csv('/content/item_properties_part2.csv')
df3.head(20)
# Out:
#         timestamp  itemid    property  \
# 0   1433041200000  183478         561
# 1   1439694000000  132256         976
# 2   1435460400000  420307         921
# 3   1431831600000  403324         917
# 4   1435460400000  230701         521
# 5   1433041200000  286407         202
# 6   1438484400000  256368         888
# 7   1437879600000  307534         888
# 8   1439089200000  102767         888
# 9   1431831600000  215180          71
# 10  1435460400000  319117         202
# 11  1433041200000  377946         202
# 12  1432436400000  177411         663
# 13  1435460400000   27497          71
# 14  1431831600000  430773         283
# 15  1431226800000    8921  categoryid
# 16  1435460400000  228955         888
# 17  1433041200000  429072         575
# 18  1431226800000  362491         283
# 19  1437879600000  400708         544
#
#                                                 value
# 0                                              769062
# 1                                     n26.400 1135780
# 2                                     1149317 1257525
# 3                                             1204143
# 4                                              769062
# 5                                              820407
# 6         437265 1296497 n24.000 229949 651738 285933
# 7         150169 212349 1095303 824508 1257235 153900
# 8   5135 790941 1055803 221748 122132 n12.000 1135...
# 9                                             1096621
# 10                                             876900
# 11        235534 307222 237874 640322 1169762 1186729
# 12                                           n204.000
# 13                                            1115859
# 14       257131 82777 493871 n27636.000 906078 939413
# 15                                               1188
# 16                                            1206551
# 17                         709083 n96000011187276.000
# 18                      1283144 353870 1043378 243044
# 19                                    1055803 1164666

# %% [markdown]
# Merging the individual item properties datasets

# %%
df_properties = pd.concat([df2, df3], ignore_index=True)
df_properties.head(10)
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513
# 5  1436065200000  285026   available                                0
# 6  1434250800000   89534         213                          1121373
# 7  1431831600000  264312           6                           319724
# 8  1433646000000  229370         202                          1330310
# 9  1434250800000   98113         451                  1141052 n48.000

# %%
df_properties.shape
# Out:
# (20275902, 4)

# %% [markdown]
# Converting timestamp into a readable format

# %%
df_properties['timestamp'] = pd.to_datetime(df_properties['timestamp'], unit='ms')
df_properties.head(10)
df_properties[['timestamp']].head()

# %%
df_properties.head(10)
# Out:
#             timestamp  itemid    property                            value
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
# 5 2015-07-05 03:00:00  285026   available                                0
# 6 2015-06-14 03:00:00   89534         213                          1121373
# 7 2015-05-17 03:00:00  264312           6                           319724
# 8 2015-06-07 03:00:00  229370         202                          1330310
# 9 2015-06-14 03:00:00   98113         451                  1141052 n48.000

# %% [markdown]
# Extracting different time-based features to enhance the recommendation model

# %%
df_properties['year'] = df_properties['timestamp'].dt.year
df_properties['month'] = df_properties['timestamp'].dt.month
df_properties['day'] = df_properties['timestamp'].dt.day
df_properties['hour'] = df_properties['timestamp'].dt.hour
df_properties['weekday'] = df_properties['timestamp'].dt.weekday  # 0=Monday, 6=Sunday
df_properties.head(10)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
# 5 2015-07-05 03:00:00  285026   available                                0
# 6 2015-06-14 03:00:00   89534         213                          1121373
# 7 2015-05-17 03:00:00  264312           6                           319724
# 8 2015-06-07 03:00:00  229370         202                          1330310
# 9 2015-06-14 03:00:00   98113         451                  1141052 n48.000
#
#    year  month  day  hour  weekday
# 0  2015      6   28     3        6
# 1  2015      9    6     3        6
# 2  2015      8    9     3        6
# 3  2015      5   10     3        6
# 4  2015      5   17     3        6
# 5  2015      7    5     3        6
# 6  2015      6   14     3        6
# 7  2015      5   17     3        6
# 8  2015      6    7     3        6
# 9  2015      6   14     3        6

# %% [markdown]
# Exporting the updated dataset

# %%
df_properties.to_csv('item_properties_timestamp.csv')

# %% [markdown]
# *  Data cleaning

# %%
df_properties.head(7)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
# 5 2015-07-05 03:00:00  285026   available                                0
# 6 2015-06-14 03:00:00   89534         213                          1121373
#
#    year  month  day  hour  weekday
# 0  2015      6   28     3        6
# 1  2015      9    6     3        6
# 2  2015      8    9     3        6
# 3  2015      5   10     3        6
# 4  2015      5   17     3        6
# 5  2015      7    5     3        6
# 6  2015      6   14     3        6

# %%
item_properties = df_properties.copy()
item_properties.head(5)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
#
#    year  month  day  hour  weekday
# 0  2015      6   28     3        6
# 1  2015      9    6     3        6
# 2  2015      8    9     3        6
# 3  2015      5   10     3        6
# 4  2015      5   17     3        6

# %% [markdown]
# *  Filtering categoryid values and 'Availability' values from the property column.

# %%
# Extracting 'categoryid' values from the property column
item_properties['category_id'] = item_properties.apply(lambda x: x['value'] if x['property'] == 'categoryid' else None, axis=1)

# %%
item_properties.head(5)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
#
#    year  month  day  hour  weekday category_id
# 0  2015      6   28     3        6        1338
# 1  2015      9    6     3        6        None
# 2  2015      8    9     3        6        None
# 3  2015      5   10     3        6        None
# 4  2015      5   17     3        6        None

# %%
item_properties.to_csv('item_properties_categoryid_added.csv')

# %%
# Convert category_id to numeric
item_properties['category_id'] = pd.to_numeric(item_properties['category_id'], errors='coerce')

# Extract 'available' values into a new column
item_properties['Availability'] = 'Unknown'  # Default value
item_properties.loc[(item_properties['property'] == 'available') & (item_properties['value'] == '1'), 'Availability'] = 'Available'
item_properties.loc[(item_properties['property'] == 'available') & (item_properties['value'] == '0'), 'Availability'] = 'Not Available'

# %%
item_properties.head(7)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
# 5 2015-07-05 03:00:00  285026   available                                0
# 6 2015-06-14 03:00:00   89534         213                          1121373
#
#    year  month  day  hour  weekday  category_id   Availability
# 0  2015      6   28     3        6       1338.0        Unknown
# 1  2015      9    6     3        6          NaN        Unknown
# 2  2015      8    9     3        6          NaN        Unknown
# 3  2015      5   10     3        6          NaN        Unknown
# 4  2015      5   17     3        6          NaN        Unknown
# 5  2015      7    5     3        6          NaN  Not Available
# 6  2015      6   14     3        6          NaN        Unknown

# %%
item_properties['Availability'].value_counts()
# Out:
# Availability
# Unknown          18772263
# Not Available      863086
# Available          640553
# Name: count, dtype: int64

# %%
item_properties['category_id'].value_counts()
# Out:
# category_id
# 1147.0    26890
# 546.0     24885
# 1613.0    21126
# 491.0     19998
# 1404.0    18217
#           ...
# 308.0         1
# 930.0         1
# 1636.0        1
# 901.0         1
# 391.0         1
# Name: count, Length: 1242, dtype: int64

# %%
item_properties.head(20)
# Out:
#              timestamp  itemid    property  \
# 0  2015-06-28 03:00:00  460429  categoryid
# 1  2015-09-06 03:00:00  206783         888
# 2  2015-08-09 03:00:00  395014         400
# 3  2015-05-10 03:00:00   59481         790
# 4  2015-05-17 03:00:00  156781         917
# 5  2015-07-05 03:00:00  285026   available
# 6  2015-06-14 03:00:00   89534         213
# 7  2015-05-17 03:00:00  264312           6
# 8  2015-06-07 03:00:00  229370         202
# 9  2015-06-14 03:00:00   98113         451
# 10 2015-08-09 03:00:00  450113         888
# 11 2015-06-28 03:00:00  244127         400
# 12 2015-08-16 03:00:00  264319         227
# 13 2015-08-16 03:00:00  348323         839
# 14 2015-06-14 03:00:00  169055         790
# 15 2015-07-19 03:00:00  186518   available
# 16 2015-06-28 03:00:00  178601         790
# 17 2015-07-12 03:00:00  319291         888
# 18 2015-07-19 03:00:00   49337           0
# 19 2015-06-28 03:00:00  363598        1022
#
#                                                 value  year  month  day  hour  \
# 0                                                1338  2015      6   28     3
# 1                             1116713 960601 n277.200  2015      9    6     3
# 2                     n552.000 639502 n720.000 424566  2015      8    9     3
# 3                                          n15360.000  2015      5   10     3
# 4                                              828513  2015      5   17     3
# 5                                                   0  2015      7    5     3
# 6                                             1121373  2015      6   14     3
# 7                                              319724  2015      5   17     3
# 8                                             1330310  2015      6    7     3
# 9                                     1141052 n48.000  2015      6   14     3
# 10                             1038400 45956 n504.000  2015      8    9     3
# 11                    n552.000 639502 n720.000 424566  2015      6   28     3
# 12                                     1283144 353870  2015      8   16     3
# 13                                    1026952 1162729  2015      8   16     3
# 14                                         n21000.000  2015      6   14     3
# 15                                                  0  2015      7   19     3
# 16                                          n5400.000  2015      6   28     3
# 17                                            1292080  2015      7   12     3
# 18  n36.000 1186610 119932 717520 903287 98606 632...  2015      7   19     3
# 19                                      857891 593337  2015      6   28     3
#
#     weekday  category_id   Availability
# 0         6       1338.0        Unknown
# 1         6          NaN        Unknown
# 2         6          NaN        Unknown
# 3         6          NaN        Unknown
# 4         6          NaN        Unknown
# 5         6          NaN  Not Available
# 6         6          NaN        Unknown
# 7         6          NaN        Unknown
# 8         6          NaN        Unknown
# 9         6          NaN        Unknown
# 10        6          NaN        Unknown
# 11        6          NaN        Unknown
# 12        6          NaN        Unknown
# 13        6          NaN        Unknown
# 14        6          NaN        Unknown
# 15        6          NaN  Not Available
# 16        6          NaN        Unknown
# 17        6          NaN        Unknown
# 18        6          NaN        Unknown
# 19        6          NaN        Unknown

# %%
item_properties.to_csv('item_properties_availability_added.csv')

# %%
events = pd.read_csv('/content/events.csv')
events.head(10)
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN
# 5  1433224086234     972639  view   22556            NaN
# 6  1433221923240     810725  view  443030            NaN
# 7  1433223291897     794181  view  439202            NaN
# 8  1433220899221     824915  view  428805            NaN
# 9  1433221204592     339335  view   82389            NaN

# %% [markdown]
# # Further data cleaning

# %% [markdown]
# *  Handling 'Item_property' Time-Dependence

# %%
item_properties.head(5)
# Out:
#             timestamp  itemid    property                            value  \
# 0 2015-06-28 03:00:00  460429  categoryid                             1338
# 1 2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2 2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3 2015-05-10 03:00:00   59481         790                       n15360.000
# 4 2015-05-17 03:00:00  156781         917                           828513
#
#    year  month  day  hour  weekday  category_id Availability
# 0  2015      6   28     3        6       1338.0      Unknown
# 1  2015      9    6     3        6          NaN      Unknown
# 2  2015      8    9     3        6          NaN      Unknown
# 3  2015      5   10     3        6          NaN      Unknown
# 4  2015      5   17     3        6          NaN      Unknown

# %%
# This keeps only the latest property value for each itemid
item_properties = item_properties.sort_values(by=['itemid', 'timestamp'], ascending=[True, False])
item_properties_latest = item_properties.drop_duplicates(subset=['itemid'], keep='first')

# %% [markdown]
# *  Handling hashed and encoded values

# %%
# Converting numerical columns from string format to float
item_properties['value'] = item_properties['value'].str.replace('n', '').str.replace(' ', '').astype(float)

# %% [markdown]
# *  Detecting and removing abnormal Users (Possibly bots)

# %%
events.head(5)
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
# Counting user actions
user_activity = events.groupby('visitorid').agg({'event': 'count'})

# Defining threshold for abnormal behavior
abnormal_users = user_activity[user_activity['event'] > 1000].index

# Removing abnormal users
events_cleaned = events[~events['visitorid'].isin(abnormal_users)]

# %%
events.head(5)
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
events.to_csv('events_cleaned.csv')

# %% [markdown]
# *  Merging item_properties dataframe and events dataframe

# %%
item_properties = pd.read_csv('/content/item_properties_availability_added.csv')

# %%
events_cleaned.head(5)
# Out:
#    Unnamed: 0      timestamp  visitorid event  itemid  transactionid
# 0           0  1433221332117     257597  view  355908            NaN
# 1           1  1433224214164     992329  view  248676            NaN
# 2           2  1433221999827     111016  view  318965            NaN
# 3           3  1433221955914     483717  view  253185            NaN
# 4           4  1433221337106     951259  view  367447            NaN

# %%
events_cleaned['timestamp'] = pd.to_datetime(events_cleaned['timestamp'], unit='ms')
events_cleaned.head(10)

events_cleaned['year'] = events_cleaned['timestamp'].dt.year
events_cleaned['month'] = events_cleaned['timestamp'].dt.month
events_cleaned['day'] = events_cleaned['timestamp'].dt.day
events_cleaned['hour'] = events_cleaned['timestamp'].dt.hour
events_cleaned['weekday'] = events_cleaned['timestamp'].dt.weekday  # 0=Monday, 6=Sunday
events_cleaned.head(10)
# Out:
#    Unnamed: 0               timestamp  visitorid event  itemid  transactionid  \
# 0           0 2015-06-02 05:02:12.117     257597  view  355908            NaN
# 1           1 2015-06-02 05:50:14.164     992329  view  248676            NaN
# 2           2 2015-06-02 05:13:19.827     111016  view  318965            NaN
# 3           3 2015-06-02 05:12:35.914     483717  view  253185            NaN
# 4           4 2015-06-02 05:02:17.106     951259  view  367447            NaN
# 5           5 2015-06-02 05:48:06.234     972639  view   22556            NaN
# 6           6 2015-06-02 05:12:03.240     810725  view  443030            NaN
# 7           7 2015-06-02 05:34:51.897     794181  view  439202            NaN
# 8           8 2015-06-02 04:54:59.221     824915  view  428805            NaN
# 9           9 2015-06-02 05:00:04.592     339335  view   82389            NaN
#
#    year  month  day  hour  weekday
# 0  2015      6    2     5        1
# 1  2015      6    2     5        1
# 2  2015      6    2     5        1
# 3  2015      6    2     5        1
# 4  2015      6    2     5        1
# 5  2015      6    2     5        1
# 6  2015      6    2     5        1
# 7  2015      6    2     5        1
# 8  2015      6    2     4        1
# 9  2015      6    2     5        1

# %%
events_cleaned = events_cleaned.drop('Unnamed: 0', axis=1)
events_cleaned.head(5)
# Out:
#                 timestamp  visitorid event  itemid  transactionid  year  \
# 0 2015-06-02 05:02:12.117     257597  view  355908            NaN  2015
# 1 2015-06-02 05:50:14.164     992329  view  248676            NaN  2015
# 2 2015-06-02 05:13:19.827     111016  view  318965            NaN  2015
# 3 2015-06-02 05:12:35.914     483717  view  253185            NaN  2015
# 4 2015-06-02 05:02:17.106     951259  view  367447            NaN  2015
#
#    month  day  hour  weekday
# 0      6    2     5        1
# 1      6    2     5        1
# 2      6    2     5        1
# 3      6    2     5        1
# 4      6    2     5        1

# %%
item_properties.head(5)
# Out:
#    Unnamed: 0            timestamp  itemid    property  \
# 0           0  2015-06-28 03:00:00  460429  categoryid
# 1           1  2015-09-06 03:00:00  206783         888
# 2           2  2015-08-09 03:00:00  395014         400
# 3           3  2015-05-10 03:00:00   59481         790
# 4           4  2015-05-17 03:00:00  156781         917
#
#                              value  year  month  day  hour  weekday  \
# 0                             1338  2015      6   28     3        6
# 1          1116713 960601 n277.200  2015      9    6     3        6
# 2  n552.000 639502 n720.000 424566  2015      8    9     3        6
# 3                       n15360.000  2015      5   10     3        6
# 4                           828513  2015      5   17     3        6
#
#    category_id Availability
# 0       1338.0      Unknown
# 1          NaN      Unknown
# 2          NaN      Unknown
# 3          NaN      Unknown
# 4          NaN      Unknown

# %%
item_properties = item_properties.drop('Unnamed: 0', axis=1)
item_properties.head(5)
# Out:
#              timestamp  itemid    property                            value  \
# 0  2015-06-28 03:00:00  460429  categoryid                             1338
# 1  2015-09-06 03:00:00  206783         888          1116713 960601 n277.200
# 2  2015-08-09 03:00:00  395014         400  n552.000 639502 n720.000 424566
# 3  2015-05-10 03:00:00   59481         790                       n15360.000
# 4  2015-05-17 03:00:00  156781         917                           828513
#
#    year  month  day  hour  weekday  category_id Availability
# 0  2015      6   28     3        6       1338.0      Unknown
# 1  2015      9    6     3        6          NaN      Unknown
# 2  2015      8    9     3        6          NaN      Unknown
# 3  2015      5   10     3        6          NaN      Unknown
# 4  2015      5   17     3        6          NaN      Unknown

# %%
item_properties = item_properties.drop('property', axis=1)
item_properties.head(5)
# Out:
#              timestamp  itemid                            value  year  month  \
# 0  2015-06-28 03:00:00  460429                             1338  2015      6
# 1  2015-09-06 03:00:00  206783          1116713 960601 n277.200  2015      9
# 2  2015-08-09 03:00:00  395014  n552.000 639502 n720.000 424566  2015      8
# 3  2015-05-10 03:00:00   59481                       n15360.000  2015      5
# 4  2015-05-17 03:00:00  156781                           828513  2015      5
#
#    day  hour  weekday  category_id Availability
# 0   28     3        6       1338.0      Unknown
# 1    6     3        6          NaN      Unknown
# 2    9     3        6          NaN      Unknown
# 3   10     3        6          NaN      Unknown
# 4   17     3        6          NaN      Unknown

# %%
item_properties.to_csv('item_properties_updated.csv')

# %%
events_cleaned.head(5)
# Out:
#                 timestamp  visitorid event  itemid  transactionid  year  \
# 0 2015-06-02 05:02:12.117     257597  view  355908            NaN  2015
# 1 2015-06-02 05:50:14.164     992329  view  248676            NaN  2015
# 2 2015-06-02 05:13:19.827     111016  view  318965            NaN  2015
# 3 2015-06-02 05:12:35.914     483717  view  253185            NaN  2015
# 4 2015-06-02 05:02:17.106     951259  view  367447            NaN  2015
#
#    month  day  hour  weekday
# 0      6    2     5        1
# 1      6    2     5        1
# 2      6    2     5        1
# 3      6    2     5        1
# 4      6    2     5        1

# %%
events_cleaned.to_csv('events_timestamp_added.csv')

# %% [markdown]
# #   Merging the item_properties dataset with events dataset

# %%
events_cleaned = pd.read_csv('/content/events_timestamp_added.csv')
items_properties = pd.read_csv('/content/item_properties_updated.csv')

# %%
events_cleaned.head(5)
# Out:
#    Unnamed: 0                timestamp  visitorid event  itemid  \
# 0           0  2015-06-02 05:02:12.117     257597  view  355908
# 1           1  2015-06-02 05:50:14.164     992329  view  248676
# 2           2  2015-06-02 05:13:19.827     111016  view  318965
# 3           3  2015-06-02 05:12:35.914     483717  view  253185
# 4           4  2015-06-02 05:02:17.106     951259  view  367447
#
#    transactionid  year  month  day  hour  weekday
# 0            NaN  2015      6    2     5        1
# 1            NaN  2015      6    2     5        1
# 2            NaN  2015      6    2     5        1
# 3            NaN  2015      6    2     5        1
# 4            NaN  2015      6    2     5        1

# %%
items_properties.head(5)
# Out:
#    Unnamed: 0            timestamp  itemid                            value  \
# 0           0  2015-06-28 03:00:00  460429                             1338
# 1           1  2015-09-06 03:00:00  206783          1116713 960601 n277.200
# 2           2  2015-08-09 03:00:00  395014  n552.000 639502 n720.000 424566
# 3           3  2015-05-10 03:00:00   59481                       n15360.000
# 4           4  2015-05-17 03:00:00  156781                           828513
#
#    year  month  day  hour  weekday  category_id Availability
# 0  2015      6   28     3        6       1338.0      Unknown
# 1  2015      9    6     3        6          NaN      Unknown
# 2  2015      8    9     3        6          NaN      Unknown
# 3  2015      5   10     3        6          NaN      Unknown
# 4  2015      5   17     3        6          NaN      Unknown

# %%
# Sort by itemid and timestamp
events_cleaned.sort_values(["timestamp", "itemid"], inplace=True)
items_properties.sort_values(["timestamp", "itemid"], inplace=True)

# Drop unnecessary time breakdown columns after sorting
events_sorted = events_cleaned.drop(columns=["year", "month", "day", "hour", "minute", "second"], errors="ignore")
items_sorted = items_properties.drop(columns=["year", "month", "day", "hour", "minute", "second"], errors="ignore")

# Assuming 'timestamp' is a Unix timestamp in milliseconds
events_sorted['timestamp'] = pd.to_datetime(events_sorted['timestamp'], unit='ms', errors='coerce')
items_sorted['timestamp'] = pd.to_datetime(items_sorted['timestamp'], unit='ms', errors='coerce')

# Ensure 'itemid' columns have the same dtype before merging
# Convert 'itemid' to numeric, handling errors by coercing to NaN
events_sorted['itemid'] = pd.to_numeric(events_sorted['itemid'], errors='coerce')
items_sorted['itemid'] = pd.to_numeric(items_sorted['itemid'], errors='coerce')

# Fill NaN values with a suitable integer (e.g., -1) or drop rows with NaN
events_sorted['itemid'] = events_sorted['itemid'].fillna(-1).astype('int64')
items_sorted['itemid'] = items_sorted['itemid'].fillna(-1).astype('int64')

# Merge using nearest timestamp match within each itemid group
items_enhanced = pd.merge_asof(
    events_sorted,
    items_sorted,
    on="timestamp",
    by="itemid",
    direction="backward",
    tolerance=pd.Timedelta(days=1)
)

# Define the desired column order
column_order = [
    'timestamp', 'visitorid', 'event', 'transactionid', 'itemid', 'categoryid', 'parentid',
    'available', 'description']

# Reorder the DataFrame
items_enhanced = items_enhanced[column_order]

# Display results
print(f"Merged dataset size: {items_enhanced.shape}")
items_enhanced
